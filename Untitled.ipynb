# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.tree import export_graphviz

# %%
path = "Final_Dataset.csv"
life_df = pd.read_csv(path)
print("Shape of dataframe",life_df.shape)
life_df.head()
# Out:
# Shape of dataframe (990, 30)
#        Country  Year  cervical_cancer_number_of_new_female_cases  \
# 0  Afghanistan  2000                                       776.0
# 1  Afghanistan  2001                                       800.0
# 2  Afghanistan  2002                                       820.0
# 3  Afghanistan  2003                                       842.0
# 4  Afghanistan  2004                                       867.0
#
#    co2_intensity_of_economic_output_kg_co2_per_2011_ppp_of_gdp  \
# 0                                                NaN
# 1                                                NaN
# 2                                             0.0458
# 3                                             0.0471
# 4                                             0.0371
#
#    cumulative_co2_emissions_tonnes  liver_cancer_number_of_new_male_cases  \
# 0                       72000000.0                                  178.0
# ...

# %%
#cleaning and exploring dataframe
life_df = life_df.dropna(inplace=False)
print(life_df.shape)
life_df.head()
# Out:
# (109, 30)
#        Country  Year  cervical_cancer_number_of_new_female_cases  \
# 10     Albania  2001                                       114.0
# 17     Albania  2008                                       131.0
# 24     Algeria  2006                                       871.0
# 46     Armenia  2001                                       342.0
# 61  Azerbaijan  2007                                       631.0
#
#     co2_intensity_of_economic_output_kg_co2_per_2011_ppp_of_gdp  \
# 10                                              0.171
# 17                                              0.162
# 24                                              0.242
# 46                                              0.360
# 61                                              0.268
#
#     cumulative_co2_emissions_tonnes  liver_cancer_number_of_new_male_cases  \
# 10                     2.000000e+08                                  209.0
# ...

# %%
#Label encoding the values to be provided as input for label encoding
input_df = life_df[['Country','Year','co2_intensity_of_economic_output_kg_co2_per_2011_ppp_of_gdp','liver_cancer_number_of_new_male_cases','flood_affected_annual_number','food_supply_kilocalories_per_person_and_day','literacy_rate_adult_total_percent_of_people_ages_15_and_above','literacy_rate_youth_total_percent_of_people_ages_15_24']]
input_df.head()
# Out:
#        Country  Year  \
# 10     Albania  2001
# 17     Albania  2008
# 24     Algeria  2006
# 46     Armenia  2001
# 61  Azerbaijan  2007
#
#     co2_intensity_of_economic_output_kg_co2_per_2011_ppp_of_gdp  \
# 10                                              0.171
# 17                                              0.162
# 24                                              0.242
# 46                                              0.360
# 61                                              0.268
#
#     liver_cancer_number_of_new_male_cases  flood_affected_annual_number  \
# 10                                  209.0                             0
# 17                                  201.0                             0
# 24                                  224.0                         60000
# 46                                  150.0                             0
# 61                                  294.0                             0
#
#     food_supply_kilocalories_per_person_and_day  \
# ...

# %%
target_df = life_df[['Life']]
target_df.head()
# Out:
#     Life
# 10  73.6
# 17  75.3
# 24  73.4
# 46  72.6
# 61  73.0

# %%
#label encoder for the dataset
le = preprocessing.LabelEncoder()
encoded_X = input_df.apply(le.fit_transform)
encoded_X.shape
# Out:
# (109, 8)

# %%
Y = target_df
Y.shape
# Out:
# (109, 1)

# %%
#spliting dataset into training and test dataset
#spliting the dataset into test and training dataset 
X_train, X_test, y_train, y_test =  train_test_split(encoded_X, Y, test_size=0.2, random_state=42)

#using decision tree regressor and predicting the values
regr = DecisionTreeRegressor(random_state = 0)
# regr.fit(encoded_X, Y)
regr.fit(X_train,y_train)
y_pred = regr.predict(X_test)

#using mean square method to determine how effecient the algorithm is
print("Mean squre error for Decision tree regressor using test data is: ",np.sqrt(mean_squared_error(y_test, y_pred)))

#Similarly applying the same for test data set and finding the mean square error
regr = DecisionTreeRegressor(random_state = 0)
regr.fit(X_test,y_test)
y_pred = regr.predict(X_test)
print("Mean squre error for Decision tree regressor using train data is: ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean squre error for Decision tree regressor using test data is:  3.3411348099383553
# Mean squre error for Decision tree regressor using train data is:  0.0

# %%
# export_graphout_file ='tree.dot',feature_names =['Country','Year','co2_intensity_of_economic_output_kg_co2_per_2011_ppp_of_gdp','liver_cancer_number_of_new_male_cases','flood_affected_annual_number','food_supply_kilocalories_per_person_and_day','literacy_rate_adult_total_percent_of_people_ages_15_and_above','literacy_rate_youth_total_percent_of_people_ages_15_24'],
# filled=True,rounded=True)


from graphviz import Source

from IPython.display import SVG
graph = Source( export_graphviz(regr, out_file ='None', 
               feature_names =['Country','Year','co2_intensity_of_economic_output_kg_co2_per_2011_ppp_of_gdp','liver_cancer_number_of_new_male_cases','flood_affected_annual_number','food_supply_kilocalories_per_person_and_day','literacy_rate_adult_total_percent_of_people_ages_15_and_above','literacy_rate_youth_total_percent_of_people_ages_15_24'])
)
SVG(graph.pipe(format='svg'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     145     try:
# --> 146         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     147     except OSError as e:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...
